# %% [markdown]
# ___
#
# <a href='https://www.udemy.com/user/joseportilla/'><img src='../../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Content Copyright by Pierian Data</em></center>

# %% [markdown]
# # Advanced Modules Exercise Puzzle
#
# It's time to test your new skills, this puzzle project will combine multiple skills sets, including unzipping files with Python, using os module to automatically search through lots of files.
#
# ## Your Goal
#
# This is a puzzle, so we don't want to give you too much guidance and instead have you figure out things on your own.
#
# There is a .zip file called 'unzip_me_for_instructions.zip', unzip it, open the .txt file with Python, read the instructions and see if you can figure out what you need to do!
#
# **If you get stuck or don't know where to start, here is a [guide/hints](https://docs.google.com/document/d/1JxydUr4n4fSR0EwwuwT-aHia-yPK6r-oTBuVT2sqheo/edit?usp=sharing)**

# %%
import shutil

# %%
shutil.unpack_archive("unzip_me_for_instructions.zip", "Puzzle Instructions", "zip")

# %%
import os
import re

# %%
dir_path = os.getcwd()
dir_path
# Out:
# 'C:\\Users\\KaranJJoshi\\Python Bootcamp Karan Joshi\\14 Advanced Python Modules'

# %%
for folder, sub_folders, files in os.walk(dir_path+"\\Puzzle Instructions\\extracted_content"):
    base_path = dir_path+"\\Puzzle Instructions\\extracted_content"
    print(f"Currently looking at folder{folder} \n")
    print(f"Sub Folders are : \n")
    for sub_folder in sub_folders:
        print(f"\t {sub_folder}")
    print(f"\nThe Files are: \n")
    for file in files:
        print(f"{base_path}\\{folder}\\{file}")
        # print(f"{file}")
        # with open(base_path+"\\"+folder, "r") as f:
        #     file_content = f.read()
        #     print(file_content)
# Out:
# Currently looking at folderC:\Users\KaranJJoshi\Python Bootcamp Karan Joshi\14 Advanced Python Modules\Puzzle Instructions\extracted_content
#
# Sub Folders are :
#
# 	 .ipynb_checkpoints
# 	 Five
# 	 Four
# 	 One
# 	 Three
# 	 Two
#
# The Files are:
#
# Instructions.txt
# Currently looking at folderC:\Users\KaranJJoshi\Python Bootcamp Karan Joshi\14 Advanced Python Modules\Puzzle Instructions\extracted_content\.ipynb_checkpoints
#
# Sub Folders are :
#
#
# The Files are:
#
# Instructions-checkpoint.txt
# Currently looking at folderC:\Users\KaranJJoshi\Python Bootcamp Karan Joshi\14 Advanced Python Modules\Puzzle Instructions\extracted_content\Five
#
# Sub Folders are :
#
#
# The Files are:
#
# AEITMYIRQLP.txt
# APJKSRITGGX.txt
# AQKATDFGXTS.txt
# ARLKFCWIAJE.txt
# AXJGVPVEFAS.txt
# BNUQEHCFRTG.txt
# BSKJDRNEZQM.txt
# BTYWAHLHKBM.txt
# BUGKBZWRRVI.txt
# BVBURZZCAPR.txt
# CAHBEVSVDDN.txt
# COMGMZBJAYE.txt
# CRFSDGYFSHA.txt
# CSCLFZCDYYC.txt
# CXBVCTRBBIE.txt
# DDLASODUVPX.txt
# DHZBAAYEADM.txt
# DQPZQLBCJYP.txt
# DYOPIIVMZOO.txt
# DZUWWXYIAEL.txt
# EAAOEPSAWMQ.txt
# EIPWXMQZJKU.txt
# ESIZWBHMGDP.txt
# ETCUEXWNBCF.txt
# EYTCGIOYWIW.txt
# Currently looking at folderC:\Users\KaranJJoshi\Python Bootcamp Karan Joshi\14 Advanced Python Modules\Puzzle Instructions\extracted_content\Four
#
# Sub Folders are :
#
#
# The Files are:
#
# ECIOBYCDVFI.txt
# EMTGPSXQEJX.txt
# EPRNUHRSESC.txt
# ESDIZXHYCVY.txt
# EXVQSVBQQQH.txt
# QCTCKDIBBVG.txt
# QCWCFLKNZMN.txt
# QDDETWBHJYC.txt
# QTDYYIFPHAU.txt
# QVNJULGXNUM.txt
# REAXWSOIQDY.txt
# ROICPTWKXDX.txt
# RSXOTNGKBML.txt
# RXDARIDGKBF.txt
# RYNXFYXMKHG.txt
# TAKNAVDMZKV.txt
# THPNEGKTJWI.txt
# TJFMLJODVAD.txt
# TKCZSFQNJTX.txt
# TWUOYFCCYBQ.txt
# WFSKPTXPFCH.txt
# WHTOHQUWXIN.txt
# WNJISWPEBRS.txt
# WXDJDOGZEHN.txt
# WYDLGSGGXKV.txt
# Currently looking at folderC:\Users\KaranJJoshi\Python Bootcamp Karan Joshi\14 Advanced Python Modules\Puzzle Instructions\extracted_content\One
#
# Sub Folders are :
#
# 	 .ipynb_checkpoints
#
# The Files are:
#
# HDOHZHFSTTK.txt
# HFUTPPAXDIS.txt
# HMNZTLIFGPD.txt
# HRQFTHKVJTL.txt
# HVUTZEVMSBW.txt
# JDLRVFCXYLU.txt
# JEHBLZPUPSP.txt
# JLTXKIGCWDL.txt
# JQUOBKFUACN.txt
# JTHSNBNPQSE.txt
# KCXGNQCZBLO.txt
# KFIUZFERLET.txt
# KMMLGJOWLGI.txt
# KNBSKDREHQU.txt
# KTXDHIOKAUI.txt
# LDGOCUQJNNS.txt
# LFEATJAAYDC.txt
# LHODFIKVTQA.txt
# LIFDHOFKWOI.txt
# LPNDVDXPZIG.txt
# PDJMSMNKIRM.txt
# PHWAVPEKAER.txt
# PLYCGPVEAWO.txt
# PQNVCVJINAR.txt
# PTOBBCJYURJ.txt
# Currently looking at folderC:\Users\KaranJJoshi\Python Bootcamp Karan Joshi\14 Advanced Python Modules\Puzzle Instructions\extracted_content\One\.ipynb_checkpoints
#
# Sub Folders are :
#
#
# The Files are:
#
# HDOHZHFSTTK-checkpoint.txt
# Currently looking at folderC:\Users\KaranJJoshi\Python Bootcamp Karan Joshi\14 Advanced Python Modules\Puzzle Instructions\extracted_content\Three
#
# Sub Folders are :
#
#
# The Files are:
#
# VAQIJTDOFUJ.txt
# VCFJCGJFBIH.txt
# VSXFSTABZDY.txt
# VVHFVZUNLOO.txt
# VVKGWLRMHLU.txt
# XAJMCPEWFNI.txt
# XFHJOTNPEJG.txt
# XHZPVUQTXIO.txt
# XJCWENFFGHB.txt
# XVMPVSVYKFR.txt
# YCESZHJDBXH.txt
# YDQFMWXOUMW.txt
# YQBIUHSUEVW.txt
# YQRNCMNFFHW.txt
# YYIZGBTQHZP.txt
# ZEZKKRBIZEB.txt
# ZKQJXAYKPVD.txt
# ZOWVXWPOGWP.txt
# ZXEZRQXZNPG.txt
# ZXIBJMPROKW.txt
# Currently looking at folderC:\Users\KaranJJoshi\Python Bootcamp Karan Joshi\14 Advanced Python Modules\Puzzle Instructions\extracted_content\Two
#
# Sub Folders are :
#
#
# The Files are:
#
# GKQBQRCTNNK.txt
# GMMQQUBMJNR.txt
# GQTJJORZBXY.txt
# GTOTCIWMDBY.txt
# GXYSEPAFRTP.txt
# HARDNJGDRBC.txt
# HEORIXOTANT.txt
# HMUTDOVNYTV.txt
# HMZXPBOPRAE.txt
# HTOHSTYXTCO.txt
# LCJZYDHBFRM.txt
# LSQSTGPIGIY.txt
# LULTNYAQEJG.txt
# LVMBINRBJXL.txt
# LYZEQCVYNEZ.txt
# OHZOUOSFJQC.txt
# OIHMLGMWTHL.txt
# OKWFOOYTXFU.txt
# OMWIMVRCMYM.txt
# OYMAGXAGWHJ.txt
# SIKFPPLCJDN.txt
# SJMJLDGPBSJ.txt
# SOFUJYXTIMK.txt
# SPDZYGDHEWO.txt
# SWOFXREEHWA.txt
